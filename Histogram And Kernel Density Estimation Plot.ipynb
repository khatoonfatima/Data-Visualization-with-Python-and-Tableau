# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
data=pd.read_csv(r"C:\Users\khato\OneDrive\Desktop\Lecture 25.csv",header=None)

# %%
data
# Out:
#    0  1  2  3        4
# 0  q  r  s  t   apple
# 1  2  3  4  5    pear
# 2  a  s  d  f  rabbit
# 3  5  2  5  7     dog

# %%
#delimiter , is use to separate everything

#here we are reading only 2 rows

pd.read_csv(r'C:\Users\khato\OneDrive\Desktop\Lecture 25.csv',header=None,nrows=2)
# Out:
#    0  1  2  3       4
# 0  q  r  s  t  apple
# 1  2  3  4  5   pear

# %%
data
# Out:
#    0  1  2  3        4
# 0  q  r  s  t   apple
# 1  2  3  4  5    pear
# 2  a  s  d  f  rabbit
# 3  5  2  5  7     dog

# %%
data.to_csv('mytextdata_out.csv')

# %%
import sys

# %%
data.to_csv(sys.stdout,sep='_')
# Out:
# _0_1_2_3_4
# 0_q_r_s_t_apple
# 1_2_3_4_5_pear
# 2_a_s_d_f_rabbit
# 3_5_2_5_7_dog

# %%
data.to_csv(sys.stdout,sep='?')
# Out:
# ?0?1?2?3?4
# 0?q?r?s?t?apple
# 1?2?3?4?5?pear
# 2?a?s?d?f?rabbit
# 3?5?2?5?7?dog

# %%
data.to_csv(sys.stdout,columns=[0,1,2])
# Out:
# ,0,1,2
# 0,q,r,s
# 1,2,3,4
# 2,a,s,d
# 3,5,2,5

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randn

# %%
# %matplotlib inline

# %%
data1=randn(100)

# %%
from scipy import stats

# %%
plt.hist(data1)
# Out:
# (array([ 4.,  4., 11., 10., 17., 15., 22.,  6.,  9.,  2.]),
#  array([-2.32822334, -1.88831785, -1.44841237, -1.00850688, -0.5686014 ,
#         -0.12869591,  0.31120958,  0.75111506,  1.19102055,  1.63092603,
#          2.07083152]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data1,color='green')
# Out:
# (array([ 4.,  4., 11., 10., 17., 15., 22.,  6.,  9.,  2.]),
#  array([-2.32822334, -1.88831785, -1.44841237, -1.00850688, -0.5686014 ,
#         -0.12869591,  0.31120958,  0.75111506,  1.19102055,  1.63092603,
#          2.07083152]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data1,normed=True,color='red',alpha=0.5,bins=20)
plt.hist(data1,normed=True,alpha=0.5,bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-edfa200c8e07> in <module>
# ----> 1 plt.hist(data1,normed=True,color='red',alpha=0.5,bins=20)
#       2 plt.hist(data1,normed=True,alpha=0.5,bins=20)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
data2=randn(1000)
data3=randn(1000)

# %%
plt.hist(data2)
plt.hist(data3)
# Out:
# (array([  1.,   8.,  38., 129., 282., 309., 164.,  55.,  11.,   3.]),
#  array([-4.11519962, -3.30868287, -2.50216613, -1.69564938, -0.88913263,
#         -0.08261588,  0.72390087,  1.53041762,  2.33693437,  3.14345112,
#          3.94996786]),
#  <a list of 10 Patch objects>)

# %%
sns.jointplot(data2,data3)

# %%
sns.jointplot(data2,data3,kind='hex')

# %% [markdown]
# # Kernel Density Estimation PLot

# %%
import numpy as np
import pandas as pd
from numpy.random import randn



from scipy import stats


import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline
import matplotlib as mlp

# %%
data=randn(200)

# %%
sns.rugplot(data)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
plt.hist(data,alpha=0.3)
sns.rugplot(data)

# %%
#Kernel density plot will represent each of the mark wilth the Gaussian distribution

# %%
sns.rugplot(data)
x_min=data.min()-2
x_max=data.max()+2

x_axis=np.linspace(x_min,x_max,100)  #Linear spacing(Any two lines may have no more than one point in common.)

bandwidth=((4*data.std()**5)/(3*len(data)))**0.2


kernel_list=[]

for data_point in data:
    #Create  a kernel for each point and append it to the kernel_list
    kernel=stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    
    #Scale for plotting
    kernel=kernel/kernel.max()
    kernel=kernel*0.4
    
    plt.plot(x_axis,kernel,color='grey',alpha=0.5)
    
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
sns.rugplot(data)
x_min=data.min()-2
x_max=data.max()+2

x_axis=np.linspace(x_min,x_max,100)
bandwidth=((4*data.std()**5)/(3*len(data)))**0.2

kernel_list=[]

for data_point in data:
    kernel=stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    
    kernel=kernel/kernel.max()
    kernel=kernel*0.4
    
    plt.plot(x_axis,kernel,color='grey',alpha=0.4)
    plt.ylim(0,1)

# %%
sum_of_kde=np.sum(kernel_list,axis=0)
fig=plt.plot(x_axis,sum_of_kde)

# %%
sum_of_kde=np.sum(kernel_list,axis=0)
fig=plt.plot(x_axis,sum_of_kde,color='indianred')
sns.rugplot(data)
plt.yticks([])
plt.suptitle("Sum of the basis functions ")
# Out:
# Text(0.5, 0.98, 'Sum of the basis functions ')

# %%
sns.kdeplot(data)

# %%
sns.rugplot(data,color='blue')   #For more information go to kernel statistics site

for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(data,bw=bw,lw=1.8,label=bw)

# %%
kernel_options=['biw','cos','epa','gau','tri','triw']
for kern in kernel_options:
    sns.kdeplot(data,kernel=kern,label=kern,shade=True)

# %%
sns.kdeplot(data,vertical=True,shade=True)  #Check cumulative distribution function

# %%
sns.kdeplot(data,cumulative=True)

# %%
mean=[0,0]
cov=[[1,0],[0,100]]
dataset=np.random.multivariate_normal(mean,cov,1000)

# %%
dataset
# Out:
# array([[-0.29006244, -6.95743675],
#        [ 0.26050214, 16.26692844],
#        [ 1.53342498,  7.86587486],
#        ...,
#        [-0.60887485,  1.97082231],
#        [-1.42078549,  2.51051631],
#        [-0.35373382, -5.08883583]])

# %%
data=pd.DataFrame(dataset,columns=['X','Y'])

sns.kdeplot(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.kdeplot(data.X,data.Y,shade=True,color='green')

# %%
sns.kdeplot(data,bw=1)

# %%
sns.kdeplot(data,bw='silverman')

# %%
sns.jointplot('X','Y',data,kind='kde')
