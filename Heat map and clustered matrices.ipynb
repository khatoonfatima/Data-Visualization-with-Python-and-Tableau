# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mlp
import seaborn as sns
import scipy as stats
# %matplotlib inline

# %%
from numpy.random import randn

# %%
flight_dframe=sns.load_dataset('flights')

# %%
flight_dframe.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flight_dframe
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
flight_dframe=flight_dframe.pivot("year","month","passengers")

# %%
flight_dframe
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
# 1954       204       188    235    227  234   264   302     293        259
# 1955       242       233    267    269  270   315   364     347        312
# 1956       284       277    317    313  318   374   413     405        355
# 1957       315       301    356    348  355   422   465     467        404
# 1958       340       318    362    348  363   435   491     505        404
# 1959       360       342    406    396  420   472   548     559        463
# ...

# %%
sns.heatmap(flight_dframe,color='blue')

# %%
#To know the passenger in each cell

sns.heatmap(flight_dframe,annot=True,fmt='o')  #fmt is the formatting

# %%
sns.heatmap(flight_dframe,center=flight_dframe.loc[1955,'January'])

# %%
sns.heatmap(flight_dframe,center=flight_dframe.loc[1955,'July'])

# %%
sns.violinplot(flight_dframe)

# %%
sns.kdeplot(flight_dframe)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.boxplot(flight_dframe)

# %%
f,(axis1,axis2)=plt.subplots(2,1)

yearly_flights=flight_dframe.sum()

years=pd.Series(yearly_flights.index.values)

years=pd.DataFrame(years)

flights=pd.Series(yearly_flights.values)

flights=pd.DataFrame(flights)


#Now creating the dataframe by creating the coulmns

year_dframe=pd.concat((years,flights),axis=1)

year_dframe.columns=['Year','Flights']

sns.barplot('Year',y='Flights',data=year_dframe,ax=axis1)

# %%
f,(axis1,axis2)=plt.subplots(2,1)

yearly_flights=flight_dframe.sum()

years=pd.Series(yearly_flights.index.values)

years=pd.DataFrame(years)

flights=pd.Series(yearly_flights.values)

flights=pd.DataFrame(flights)


#Now creating the dataframe by creating the coulmns

year_dframe=pd.concat((years,flights),axis=1)

year_dframe.columns=['Year','Flights']

sns.barplot('Year',y='Flights',data=year_dframe,ax=axis1)

sns.heatmap(flight_dframe,cmap='Blues',ax=axis2,cbar_kws={'orientation':'vertical'})

# %% [markdown]
# # CLUSTER MAP

# %%
sns.clustermap(flight_dframe)

# %%
sns.clustermap(flight_dframe,col_cluster=False)

# %%
#Standardise the dataframe
sns.clustermap(flight_dframe,standard_scale=1)

# %%
sns.clustermap(flight_dframe,standard_scale=0)

# %%
#Z-score subtracts the mean and divide by standard deviation,so that the rows have the mean of 0 and variance of 1
